# %% [markdown]
# <a href="https://colab.research.google.com/github/granttowers/Project_3/blob/main/Import_Data_to_Postgress.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url = "https://grantnickproject3.s3.ap-southeast-2.amazonaws.com/incident_data.csv"
df = pd.read_csv(url)
df.head()
# Out:
#    mine_id                                            subunit        Date  \
# 0  1200945  Dredge: Mining operations conducted from a pla...  13/10/2020
# 1   200024  Mill or preparation plant:Mill prep plant or b...   2/04/2020
# 2   200024  Mill or preparation plant:Mill prep plant or b...   9/04/2020
# 3   200024  Mill or preparation plant:Mill prep plant or b...  23/04/2020
# 4  4100991  Mill or preparation plant:Mill prep plant or b...  24/04/2020
#
#    time         inspoff    state  county                             sic  \
# 0   820   Vincennes, IN  Indiana      71                   Sand & gravel
# 1   400  Mesa North, AZ  Arizona      11                      Copper Ore
# 2   825  Mesa North, AZ  Arizona      11                      Copper Ore
# 3  1115  Mesa North, AZ  Arizona      11                      Copper Ore
# 4  1630      Dallas, TX    Texas     309  Limestone (crushed and broken)
#
#            canvass         uloc  ... exptotal expmine expjob  \
# 0  Sand and Gravel  Not labeled  ...     1.15    1.15   1.15
# 1            Metal  Not labeled  ...     0.46    0.46   0.46
# 2            Metal  Not labeled  ...     3.00    3.00   0.11
# 3            Metal  Not labeled  ...     0.77    0.77   0.52
# 4            Stone  Not labeled  ...     2.29    2.29   2.29
#
#                       injtype daystotl                  coalmetl    opercont  \
# 0          NDL (No days lost)      0.0  Metal/Nonmetal/Stone/S&G    Operator
# 1                         NaN      1.0  Metal/Nonmetal/Stone/S&G    Operator
# 2  NFDL (Nonfatal, days lost)     11.0  Metal/Nonmetal/Stone/S&G  Contractor
# 3  NFDL (Nonfatal, days lost)     22.0  Metal/Nonmetal/Stone/S&G    Operator
# 4  NFDL (Nonfatal, days lost)     10.0  Metal/Nonmetal/Stone/S&G    Operator
#
#                         district                  commod  \
# 0              C08-Vincennes, IN  Sand & gravel operator
# 1  MRM-Rocky Mountain-Denver, CO          Metal operator
# 2  MRM-Rocky Mountain-Denver, CO      Noncoal contractor
# 3  MRM-Rocky Mountain-Denver, CO          Metal operator
# 4   MSC-South Central-Dallas, TX          Stone operator
#
#                    accinj
# 0       Handling material
# 1          Unknown or NEC
# 2               Machinery
# 3  Slip or fall of person
# 4  Slip or fall of person
#
# [5 rows x 57 columns]

# %% [markdown]
# ## Drop duplicates and incomplete rows

# %%
df = df[df["deginj"].str.contains("No Injury") == False]
len(df)
# Out:
# 4843

# %% [markdown]
# ## Drop Extra columns

# %%
df_dropped = df.drop(["time","inspoff","county","canvass","uloc", "shift","tradnm","minemach","modnum", "docnum","ywtotal","ywmine","ywjob","permtort","retwork","ccidn","acccode","invstart","upaddyr","upaddno","upchngyr","upchngno","narrcm","compcode","daystotl","timesnce","district","daysstat", "coalmetl"], axis=1)
df_dropped.head()
# Out:
#    mine_id                                            subunit        Date  \
# 0  1200945  Dredge: Mining operations conducted from a pla...  13/10/2020
# 1   200024  Mill or preparation plant:Mill prep plant or b...   2/04/2020
# 2   200024  Mill or preparation plant:Mill prep plant or b...   9/04/2020
# 3   200024  Mill or preparation plant:Mill prep plant or b...  23/04/2020
# 4  4100991  Mill or preparation plant:Mill prep plant or b...  24/04/2020
#
#      state                             sic umeth  \
# 0  Indiana                   Sand & gravel     0
# 1  Arizona                      Copper Ore     0
# 2  Arizona                      Copper Ore     0
# 3  Arizona                      Copper Ore     0
# 4    Texas  Limestone (crushed and broken)     0
#
#                                                  aii  \
# 0                                  Handling material
# 1            Occupational skin diseases or disorders
# 2                                          Machinery
# 3  Slip or fall of person (from an elevation or o...
# 4  Slip or fall of person (from an elevation or o...
#
#                                                atype  injrep     sex  ...  \
# 0  Caught in-under-between a moving and stationar...       1  Female  ...
# 1           Absorption of various noxious substances       1  Female  ...
# 2                                      Struck by NEC       1  Female  ...
# 3                                  Over-exertion NEC       1  Female  ...
# 4                   Struck against stationary object       1  Female  ...
#
#    dayslost                                           narrtxt1  \
# 0       0.0  EE WAS MOVING A 2X3X.75 STEEL PLATE OFF OF A P...
# 1       0.0  EMPLOYEE STATED THAT THEIR RESPIRATOR WAS BURN...
# 2       0.0  EMPLOYEE WAS AIR CHIPPING ON CLASSIFIER DOWN B...
# 3       5.0  WHILE PULLING A WATER HOSE, THE EMPLOYEE HAD T...
# 4       0.0  AN EMPLOYEE WAS WALKING DOWN THE STAIRS WHEN T...
#
#                                             narrtxt2 exptotal expmine expjob  \
# 0                           HE TIME OF THE INCIDENT.     1.15    1.15   1.15
# 1                                                NaN     0.46    0.46   0.46
# 2  THE EMPLOYEE HAD STARTED TO USE THE SMALL AIR ...     3.00    3.00   0.11
# 3                                                NaN     0.77    0.77   0.52
# 4                                                NaN     2.29    2.29   2.29
#
#                       injtype    opercont                  commod  \
# 0          NDL (No days lost)    Operator  Sand & gravel operator
# 1                         NaN    Operator          Metal operator
# 2  NFDL (Nonfatal, days lost)  Contractor      Noncoal contractor
# 3  NFDL (Nonfatal, days lost)    Operator          Metal operator
# 4  NFDL (Nonfatal, days lost)    Operator          Stone operator
#
#                    accinj
# 0       Handling material
# 1          Unknown or NEC
# 2               Machinery
# 3  Slip or fall of person
# 4  Slip or fall of person
#
# [5 rows x 28 columns]

# %% [markdown]
# ## Rename columns

# %%
df_clean = df_dropped.rename(columns={"subunit":"Operational_Process","sic":"Resource_Mined","state":"State","umeth": "Underground_Method", "aii": "Accident_Injury_Illness_Classification", "atype": "Accident_Type", "injrep": "Injury_Count","occup": "Occupation", "mwactiv": "Activity", "sourcinj": "Source of Injury", "natinj": "Nature of Injury", "partbody": "Injured Body Part", "deginj": "Degree of Injury", "daysrest": "Days Restricted", "dayslost": "Days Lost", "sex": "Sex", "age": "Age", "exptotal": "Experience_Total", "expmine": "Experience_Mine","expjob": "Experience_Job", "injtype": "Injury_Classification", "commod": "Commodity_WorkStatus", "opercont": "Operator_Contractor", "narrtxt1": "Description_1", "narrtxt2": "Description_2", "accinj": "General_Incident_Type"})
df_clean.head()
# Out:
#    mine_id                                Operational_Process        Date  \
# 0  1200945  Dredge: Mining operations conducted from a pla...  13/10/2020
# 1   200024  Mill or preparation plant:Mill prep plant or b...   2/04/2020
# 2   200024  Mill or preparation plant:Mill prep plant or b...   9/04/2020
# 3   200024  Mill or preparation plant:Mill prep plant or b...  23/04/2020
# 4  4100991  Mill or preparation plant:Mill prep plant or b...  24/04/2020
#
#      State                  Resource_Mined Underground_Method  \
# 0  Indiana                   Sand & gravel                  0
# 1  Arizona                      Copper Ore                  0
# 2  Arizona                      Copper Ore                  0
# 3  Arizona                      Copper Ore                  0
# 4    Texas  Limestone (crushed and broken)                  0
#
#               Accident_Injury_Illness_Classification  \
# 0                                  Handling material
# 1            Occupational skin diseases or disorders
# 2                                          Machinery
# 3  Slip or fall of person (from an elevation or o...
# 4  Slip or fall of person (from an elevation or o...
#
#                                        Accident_Type  Injury_Count     Sex  \
# 0  Caught in-under-between a moving and stationar...             1  Female
# 1           Absorption of various noxious substances             1  Female
# 2                                      Struck by NEC             1  Female
# 3                                  Over-exertion NEC             1  Female
# 4                   Struck against stationary object             1  Female
#
#    ...  Days Lost                                      Description_1  \
# 0  ...        0.0  EE WAS MOVING A 2X3X.75 STEEL PLATE OFF OF A P...
# 1  ...        0.0  EMPLOYEE STATED THAT THEIR RESPIRATOR WAS BURN...
# 2  ...        0.0  EMPLOYEE WAS AIR CHIPPING ON CLASSIFIER DOWN B...
# 3  ...        5.0  WHILE PULLING A WATER HOSE, THE EMPLOYEE HAD T...
# 4  ...        0.0  AN EMPLOYEE WAS WALKING DOWN THE STAIRS WHEN T...
#
#                                        Description_2 Experience_Total  \
# 0                           HE TIME OF THE INCIDENT.             1.15
# 1                                                NaN             0.46
# 2  THE EMPLOYEE HAD STARTED TO USE THE SMALL AIR ...             3.00
# 3                                                NaN             0.77
# 4                                                NaN             2.29
#
#   Experience_Mine Experience_Job       Injury_Classification  \
# 0            1.15           1.15          NDL (No days lost)
# 1            0.46           0.46                         NaN
# 2            3.00           0.11  NFDL (Nonfatal, days lost)
# 3            0.77           0.52  NFDL (Nonfatal, days lost)
# 4            2.29           2.29  NFDL (Nonfatal, days lost)
#
#    Operator_Contractor    Commodity_WorkStatus   General_Incident_Type
# 0             Operator  Sand & gravel operator       Handling material
# 1             Operator          Metal operator          Unknown or NEC
# 2           Contractor      Noncoal contractor               Machinery
# 3             Operator          Metal operator  Slip or fall of person
# 4             Operator          Stone operator  Slip or fall of person
#
# [5 rows x 28 columns]

# %% [markdown]
# ## Write DataFrame to RDS

# %%
# Write DataFrame to table
url = "postgresql://Grant_Nick_Proj3:Grant_Nick_Proj3@grantnickproj3.ckbobg8otu11.ap-southeast-2.rds.amazonaws.com/Project_3"

from sqlalchemy import create_engine
engine = create_engine(url)

# Confirm tables
#engine.table_names()

# Create New Tables and upload data# Create New Tables and upload data
df_clean.to_sql(name='incident_data', con=engine, if_exists='append', index=True)
