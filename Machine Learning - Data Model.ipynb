# %%
from sklearn import tree
import pandas as pd
import os

# %%
df = pd.read_csv(os.path.join("Resources", "final_data.csv"))
df.head()
# Out:
#    mine_id                                Operational_Process        Date  \
# 0   101401  Underground operations:All underground operati...  18/02/2020
# 1   100697  Dredge: Mining operations conducted from a pla...   1/12/2020
# 2   100578  Dredge: Mining operations conducted from a pla...   4/02/2020
# 3   100016  Mill or preparation plant:Mill prep plant or b...  17/04/2020
# 4   100034  Mill or preparation plant:Mill prep plant or b...  12/04/2020
#
#      State    Resource_Mined Underground_Method  \
# 0  Alabama  Coal, Bituminous         Continuous
# 1  Alabama     Sand & gravel                  0
# 2  Alabama     Sand & gravel                  0
# 3  Alabama            Cement                  0
# 4  Alabama     Clay (common)                  0
#
#               Accident_Injury_Illness_Classification  \
# 0  Slip or fall of person (from an elevation or o...
# 1                                  Handling material
# 2                                  Handling material
# ...

# %%
target = df["Nature of Injury"]

# %%
#data = df[["Sex","Age", "Activity"]]

data = df[["Sex"]]


data.head()
# Out:
#       Sex
# 0  Female
# 1    Male
# 2    Male
# 3    Male
# 4    Male

# %%
data_dummies = pd.get_dummies(data)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data_dummies, target)

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# 0.31927212572373864

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=200)
rf = rf.fit(X_train, y_train)
rf.score(X_test, y_test)

# This is how we predict. 
rf.predict([[1,0]])
# Out:
# array(['Sprain, strains'], dtype=object)

# %%
X_train
# Out:
#       Sex_Female  Sex_Male
# 3854           0         1
# 4307           0         1
# 2878           0         1
# 2831           0         1
# 4537           0         1
# ...          ...       ...
# 447            0         1
# 2367           1         0
# 2031           0         1
# 2555           0         1
# 1170           0         1
#
# [3626 rows x 2 columns]

# %%
sorted(zip(clf.feature_importances_,data_dummies.columns))
# Out:
# [(0.0, 'Activity_Auger (surface mine)'),
#  (0.0, 'Activity_Caging; operate elevator; manlift; etc.'),
#  (0.0, 'Activity_Remove or position hydraulic jack'),
#  (0.0005123502241111419,
#   'Activity_Change house, bathing; changing clothes, etc.'),
#  (0.0005692780267901581, 'Activity_Ride equipment'),
#  (0.00058470181569334,
#   'Activity_Lay or repair railroad track/roadbed, switching tracks, etc.'),
#  (0.0006689016814784371, 'Activity_Advance longwall roof support'),
#  (0.0006763217583233528,
#   'Activity_Sprag/block/chock mine cars or other track equip.'),
#  (0.0007006498791263481, 'Activity_Set/remove/relocate props'),
#  (0.0007725916077866434,
#   'Activity_Couple/uncouple mine car/tractor/jeep, etc.'),
#  (0.0008104105074416175,
#   'Activity_Hang or reposition tubing/pipe/rope/wire etc.'),
#  (0.000831190264042687, 'Activity_Wetting down working place'),
#  (0.0008985604222861477, 'Activity_Rerail equipment'),
# ...
